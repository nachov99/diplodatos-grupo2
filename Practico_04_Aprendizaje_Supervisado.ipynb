# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

from sklearn.model_selection import train_test_split, GridSearchCV
# from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import precision_recall_fscore_support

# %%
# Opción para ver todas las columnas del dataset en el notebook
pd.set_option('display.max_columns', 50)

# %% [markdown]
# # Práctico 04: Aprendizaje Supervisado

# %% [markdown]
# Para finalizar nuestro modelo, aplicaremos estrategias de sampling para dividir entre train y test y haremos crossvalidation sobre train. Realizaremos pruebas con varios clasificadores y evaluaremos los resultados con múltiples métricas. Por último calcularemos el feature importance y obtendremos conclusiones.

# %% [markdown]
# ## Objetivo del práctico

# %% [markdown]
# ### Train-Validation-Test
# (obtener del práctico anterior)
# - División del dataset en train/validation/test
# - Estratificación

# %% [markdown]
# ### Preprocesamiento
# (obtener del práctico anterior)
# - Tratamiento de valores nulos
# - Estandarización
# - Encoding de variables categóricas

# %% [markdown]
# ### Definición de métricas

# %% [markdown]
# Definiremos las métricas a utilizar:
# - Accuracy
# - Precision
# - Recall
# - F1
# - AUC
# - PRAUC
#
# Además investigaremos como utilizar el classification report y confusion matrix. Adicionalmente, cómo usar crossvalidation.

# %% [markdown]
# ### Testeo con varios modelos

# %% [markdown]
# Realizaremos varios tests con diversos tipos de modelos de scikit-learn:
# - Logistic regression
# - SVM
# - Naive Bayes
# - etc
# Usaremos crossvalidation y compararemos con validation y test.

# %% [markdown]
# ### Modelos Tree Based

# %% [markdown]
# En esta instancia utilizaremos modelos que no pertenecen a la librería scikit-learn.
# Estos modelos son los más utilizados actualmente y han demostrado su efectividad en muchas competencias de Kaggle.
# Además, tienen la ventaja de que
# - XGBoost
# - LightGBM

# %% [markdown]
# ### Optimización de Hiperparámetros

# %% [markdown]
# En esta sección realizaremos varios tipos de optimización de hiperparámetros para lograr mejorar nuestras métricas.
# - Grid Search
# - Randomized Search

# %% [markdown]
# ### Explainability

# %% [markdown]
# Realizaremos feature importance y como opcional utilizaremos la librería SHAP para analizar las predicciones.

# %% [markdown]
# ### Presentación

# %% [markdown]
# Al final del práctico, es necesario hacer 3 o 4 slides que irán incluidos en la presentación final.
# Los slides deberán contener las etapas de preprocesamiento, los modelos que utilizamos, como optimizamos los hiperparámetros, cómo validamos y qué métricas utilizamos. Por último responderemos desde el punto de vista de negocio si sirve o no sirve el modelo.

# %% [markdown]
# ### Librerías recomendadas

# %% [markdown]
# Utilizaremos principalmente scikit-learn, opcionalmente xgboost y lightgbm.
# Recomiendo el siguiente material:
#
# - https://scikit-learn.org/stable/ -> Referencia de librería scikit-learn. Contiene casi todo lo que vamos a utilizar, pipelines, preprocesamiento y varios modelos.
# - https://xgboost.readthedocs.io/en/latest/ -> Librería muy utilizada debido a que tiene muy buenos resultados. Es un tipo de algoritmo "boosting tree"
# - https://lightgbm.readthedocs.io/en/latest/ -> Otra librería similar a xgboost, cada vez se usa más, debido a su facilidad de uso y buenos resultados.
# - https://shap.readthedocs.io/en/latest/index.html -> Librería SHAP, para realizar explainability y analizar predicciones.
# - https://scikit-learn.org/stable/auto_examples/model_selection/grid_search_text_feature_extraction.html#sphx-glr-auto-examples-model-selection-grid-search-text-feature-extraction-py -> Ejemplo de pipelines, cross_validation y optimización de hiperparámetros

# %% [markdown]
# ## Práctico 03: Aprendizaje Supervisado - Resolución

# %%
# Leemos el dataset con la función de pandas "read_csv"
df = pd.read_csv("data.csv", sep=";")

# %% [markdown]
# ### Train-Validation-Test

# %% [markdown]
# (Obtener el código del Práctico 03)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

def get_contactado(x):
    if x >= 999:
        return '0'
    elif x < 6:
        return '1'
    elif 5 < x < 11:
        return '2'   
    else:
        return '3'
    
def productos_financieros(x):
    if x.loan == 'yes' or x.housing == 'yes':
        return 'yes'
    else:
        return 'no'

class CatCustom(BaseEstimator, TransformerMixin):
    def __init__(self):
        return None
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        
        X["job"] = X.job.replace("unknown", X.job.mode()[0])
        X["marital"] = X.marital.replace("unknown", X.marital.mode()[0])
        X["education"] = X.education.replace("unknown", X.education.mode()[0])
        X["loan"] = X.loan.replace("unknown", X.loan.mode()[0])
        X["housing"] = X.housing.replace("unknown", X.housing.mode()[0])
        
        # Education
        X["education"] = X["education"].replace({
                            'illiterate': 'ninguno',
                            'basic.4y': 'primario',
                           'basic.6y':'primario',
                           'basic.9y': 'primario',
                           'high.school':'secundario',
                           'professional.course':'terciario',
                           'university.degree':'universitario'})
        # Creamos esta columna para ver si el usuario adquirio productos financieros
        X['productos_financieros'] = X.apply(lambda x: productos_financieros(x), axis=1)
        # Drop de columnas
        X = X.drop(['loan', 'housing'], axis=1)
        
        X = pd.get_dummies(X)
        return X
    
class NumCustom(BaseEstimator, TransformerMixin):
    def __init__(self):
        return None
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        # Borrar outliers
        '''
        cols = ['age']
        for c in cols:
            z_scores = zscore(df[c])
            abs_z_scores = np.abs(z_scores)
            filtered_entries = (abs_z_scores < 3)
            X = X[filtered_entries]
        
        X_with_nan = X[cols][X[cols].isna().any(axis=1)]
        X.merge(X_with_nan)
        '''
        
        #Contactado
        X['contactado'] = X.apply(lambda x: get_contactado(x['pdays']), axis=1)    
        
        X = X.drop(["pdays", "emp.var.rate", "cons.price.idx", "cons.conf.idx", "nr.employed", "duration"], axis=1)
        return X

# %%
from sklearn.pipeline import Pipeline

num_pipeline = Pipeline([
    ("num_custom", NumCustom())
])

cat_pipeline = Pipeline([
    ("cat_custom", CatCustom()),
])

pipeline_completo = Pipeline([
    ("num_custom", NumCustom()),
    ("cat_custom", CatCustom()),
])

# %%
df["y"] = df["y"].replace({"no": 0, "yes":1})

# %%
X = df.drop(columns='y')
y = df.y

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_temp.shape, y_temp.shape, X_test.shape, y_test.shape
# Out:
# ((32950, 20), (32950,), (8238, 20), (8238,))

# %%
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.2, stratify=y_temp, random_state=42)

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((26360, 20), (26360,), (6590, 20), (6590,))

# %% [markdown]
# ### Preprocesamiento

# %%
X_train = pipeline_completo.fit_transform(X=X_train)
# Out:
# /tmp/ipykernel_180/748937091.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['contactado'] = X.apply(lambda x: get_contactado(x['pdays']), axis=1)

# %% [markdown]
# (Obtener el código del Práctico 03)

# %% [markdown]
# ### Definición de métricas

# %% [markdown]
# Justificar que métricas se utilizarán:
# - Accuracy
# - Precision
# - Recall
# - F1
# - AUC
# - PRAUC

# %% [markdown]
# Explicación de las métricas utilizadas a un stakeholder no técnico

# %%
# Por ejemplo: nuestro modelo identifica a los clientes que adquieren un plazo fijo.
# PRECISION: de los clientes que nuestro modelo dicen que van a convertir, precision nos indica el porcentaje que convirtieron realmente.
# Si nuestro modelo nos indica que 80 clientes van a convertir y tenemos un precision de 50% esto quiere decir que realmente convierten 40 clientes.

# %% [markdown]
# ### Testeo con varios modelos

# %% [markdown]
# Realizaremos varios tests con diversos tipos de modelos de scikit-learn:
# - Logistic regression
# - SVM
# - Naive Bayes
# - etc
# Usaremos crossvalidation y compararemos con validation y test.

# %%
import mlflow

# %%
X_test = pipeline_completo.fit_transform(X=X_test)
# Out:
# /tmp/ipykernel_180/748937091.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['contactado'] = X.apply(lambda x: get_contactado(x['pdays']), axis=1)

# %%
train_cols = set(X_train.columns.to_list())
test_cols = set(X_test.columns.to_list())

# %%
train_cols - test_cols
# Out:
# {'default_yes'}

# %%
X_test['default_yes'] = 0

# %%
X_val = pipeline_completo.fit_transform(X=X_val)
# Out:
# /tmp/ipykernel_180/748937091.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['contactado'] = X.apply(lambda x: get_contactado(x['pdays']), axis=1)

# %%
train_cols = set(X_train.columns.to_list())
val_cols = set(X_val.columns.to_list())
train_cols - val_cols
# Out:
# set()

# %%
mlflow.set_experiment("bank_experiment")

# %% [markdown]
# #### LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

with mlflow.start_run(run_name="LogRes"):

    pipeline_numerico_lineal = Pipeline([
                                 ('standard_scaler', StandardScaler()),
                                ])

    X_t = pipeline_numerico_lineal.fit_transform(X=X_train)
    X_test_linear = pipeline_numerico_lineal.transform(X=X_test)
    
    log_ref = LogisticRegression()
    log_ref.fit(X_t, y_train)
    
    y_pred_linear = log_ref.predict(X_test_linear)
    
    prec, rec, fscore, _ = precision_recall_fscore_support(y_test, y_pred_linear, average="macro")
    mlflow.log_metric("precision", prec)
    mlflow.log_metric("recall", rec)
    mlflow.log_metric("f1-score", fscore)

# %% [markdown]
# #### Decision Tree Clf

# %%
from sklearn.tree import DecisionTreeClassifier

with mlflow.start_run(run_name="DTC"):
    clf = DecisionTreeClassifier(random_state=42)
    clf.fit(X_train, y_train)
    
    prec, rec, fscore, _ = precision_recall_fscore_support(y_test, clf.predict(X_test), average="macro")
    mlflow.log_metric("precision", prec)
    mlflow.log_metric("recall", rec)
    mlflow.log_metric("f1-score", fscore)

# %% [markdown]
# #### SVM

# %%
from sklearn.svm import SVC

with mlflow.start_run(run_name="SVC"):
    clf = SVC(random_state=42)
    clf.fit(X_train, y_train)
    
    prec, rec, fscore, _ = precision_recall_fscore_support(y_test, clf.predict(X_test), average="macro")
    mlflow.log_metric("precision", prec)
    mlflow.log_metric("recall", rec)
    mlflow.log_metric("f1-score", fscore)

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

with mlflow.start_run(run_name="Naive Bayes"):
    clf = BernoulliNB()
    clf.fit(X_train, y_train)
    
    prec, rec, fscore, _ = precision_recall_fscore_support(y_test, clf.predict(X_test), average="macro")
    mlflow.log_metric("precision", prec)
    mlflow.log_metric("recall", rec)
    mlflow.log_metric("f1-score", fscore)

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

with mlflow.start_run(run_name="RFC"):
    clf = RandomForestClassifier(random_state=42)
    clf.fit(X_train, y_train)
    
    prec, rec, fscore, _ = precision_recall_fscore_support(y_test, clf.predict(X_test), average="macro")
    mlflow.log_metric("precision", prec)
    mlflow.log_metric("recall", rec)
    mlflow.log_metric("f1-score", fscore)

# %% [markdown]
# #### XGBoost

# %%
from xgboost import XGBClassifier

with mlflow.start_run(run_name="XGBC"):
    clf = XGBClassifier(objective="binary:logistic",
                            use_label_encoder=False,
                            random_state=42)
    clf.fit(X_train, y_train)
    
    prec, rec, fscore, _ = precision_recall_fscore_support(y_test, clf.predict(X_test), average="macro")
    mlflow.log_metric("precision", prec)
    mlflow.log_metric("recall", rec)
    mlflow.log_metric("f1-score", fscore)
# Out:
# [10:04:07] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# #### LightGBM

# %%
from lightgbm import LGBMClassifier

with mlflow.start_run(run_name="LGBMC"):
    params = {
        "objective": "binary",
        "random_state": 42
    }
    mlflow.log_params(params)
    
    clf = LGBMClassifier(**params)
    clf.fit(X_train, y_train)
    
    prec, rec, fscore, _ = precision_recall_fscore_support(y_test, clf.predict(X_test), average="macro")
    mlflow.log_metric("precision", prec)
    mlflow.log_metric("recall", rec)
    mlflow.log_metric("f1-score", fscore)

# %% [markdown]
# #### MLFlow ui

# %%
# !mlflow ui
# Out:
# [2021-09-21 09:28:56 -0300] [219] [INFO] Starting gunicorn 20.1.0
# [2021-09-21 09:28:56 -0300] [219] [INFO] Listening at: http://127.0.0.1:5000 (219)
# [2021-09-21 09:28:56 -0300] [219] [INFO] Using worker: sync
# [2021-09-21 09:28:56 -0300] [221] [INFO] Booting worker with pid: 221
# ^C
# [2021-09-21 09:29:42 -0300] [219] [INFO] Handling signal: int
# [2021-09-21 09:29:42 -0300] [221] [INFO] Worker exiting (pid: 221)

# %% [markdown]
# ### Optimización de Hiperparámetros

# %% [markdown]
# En esta sección realizaremos varios tipos de optimización de hiperparámetros para lograr mejorar nuestras métricas. Elegiremos uno de los modelos (XGBoost o LightGBM) para buscar los parámetros óptimos.

# %% [markdown]
# #### Grid Search

# %% [markdown]
# ##### GS - Log Reg

# %%
from sklearn.linear_model import LogisticRegression

with mlflow.start_run(run_name="GS-logreg"):
    pipeline_numerico_lineal = Pipeline([
                                 ('standard_scaler', StandardScaler()),
                                ])

    X_t = pipeline_numerico_lineal.fit_transform(X=X_train)
    X_test_linear = pipeline_numerico_lineal.transform(X=X_test)

    param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }

    log_reg = LogisticRegression()
    grid = GridSearchCV(log_ref, param_grid, cv=5, n_jobs=-1, scoring="f1_macro")
    grid.fit(X_t, y_train)

    mlflow.log_metric("f1-score", grid.cv_results_["mean_test_score"][grid.best_index_])

# %% [markdown]
# ##### GS - DTC

# %%
from sklearn.tree import DecisionTreeClassifier

with mlflow.start_run(run_name="GS-DTC"):
    param_grid={'criterion': ["gini", "entropy"],
               'random_state': [42],
               'max_depth': [2, 3, 5, 7, 10],
               }
    clf = DecisionTreeClassifier()
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="f1_macro")
    grid.fit(X_train, y_train)

    mlflow.log_metric("f1-score", grid.cv_results_["mean_test_score"][grid.best_index_])

# %% [markdown]
# ##### GS - SVC

# %%
from sklearn.svm import SVC

with mlflow.start_run(run_name="GS-SVC"):
    param_grid = {'kernel': ['poly', 'rbf', 'sigmoid'],
                 'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
                 'gamma': [0.1, 1, 10, 100],
                 'random_state':[42]}
    clf = SVC()
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="f1_macro")
    grid.fit(X_train, y_train)
    
    mlflow.log_metric("f1-score", grid.cv_results_["mean_test_score"][grid.best_index_])

# %% [markdown]
# ##### GS - Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

with mlflow.start_run(run_name="GS - Naive Bayes"):
    param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
               'fit_prior': [False, True]}
    
    clf = BernoulliNB()
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="f1_macro", verbose=2)
    grid.fit(X_train, y_train)
    
    mlflow.log_metric("f1-score", grid.cv_results_["mean_test_score"][grid.best_index_])
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits

# %% [markdown]
# ##### GS - Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

with mlflow.start_run(run_name="GS - RFC"):
    param_grid = {'n_estimators': [500, 1000],
                 'criterion': ['gini', 'entropy'],
                  'max_depth': [2,3,5,7,10],
                  'max_features': ['auto', 'sqrt', 'log2'],
                  'bootstrap': [True, False]
                 }
    
    clf = RandomForestClassifier()
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="f1_macro", verbose=2)
    grid.fit(X_train, y_train)
    
    mlflow.log_metric("f1-score", grid.cv_results_["mean_test_score"][grid.best_index_])

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=10, max_features='sqrt',
#                        n_estimators=500)

# %% [markdown]
# ##### GS - XGBoost

# %%
from xgboost import XGBClassifier

with mlflow.start_run(run_name="GS - XGB"):
    param_grid = {'objective': ["binary:logistic"],
                  'learning_rate': [0.01, 0.1, 0.3],
                  'gamma': [0.1, 1, 10],
                  'max_depth': [2,3,5,7,10],
                  'alpha': [0.1, 1, 100],
                  'n_estimators': [500],
                  'random_state': [42],
                  'use_label_encoder': [False]
                 }
    
    clf = XGBClassifier()
    grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="f1_macro", verbose=2)
    grid.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], early_stopping_rounds=20)
    
    mlflow.log_metric("f1-score", grid.cv_results_["mean_test_score"][grid.best_index_])
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# [11:17:53] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.68648	validation_1-logloss:0.68649
# [11:17:53] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.68648	validation_1-logloss:0.68649
# [11:17:53] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.68648	validation_1-logloss:0.68648
# [11:17:53] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.68638	validation_1-logloss:0.68642
# [11:17:53] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.68648	validation_1-logloss:0.68649
# [11:17:53] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.68649	validation_1-logloss:0.68649
# [1]	validation_0-logloss:0.67994	validation_1-logloss:0.67997
# [1]	validation_0-logloss:0.67996	validation_1-logloss:0.67997
# [11:17:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.68641	validation_1-logloss:0.68641
# [11:17:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.68640	validation_1-logloss:0.68641
# [1]	validation_0-logloss:0.67977	validation_1-logloss:0.67981
# [1]	validation_0-logloss:0.67996	validation_1-logloss:0.67997
# [2]	validation_0-logloss:0.67353	validation_1-logloss:0.67357
# [1]	validation_0-logloss:0.67992	validation_1-logloss:0.67996
# [1]	validation_0-logloss:0.67993	validation_1-logloss:0.67994
# [2]	validation_0-logloss:0.67356	validation_1-logloss:0.67358
# [2]	validation_0-logloss:0.67356	validation_1-logloss:0.67356
# [1]	validation_0-logloss:0.67976	validation_1-logloss:0.67981
# [3]	validation_0-logloss:0.66727	validation_1-logloss:0.66730
# [3]	validation_0-logloss:0.66727	validation_1-logloss:0.66732
# [2]	validation_0-logloss:0.67351	validation_1-logloss:0.67353
# [1]	validation_0-logloss:0.67977	validation_1-logloss:0.67981
# [2]	validation_0-logloss:0.67350	validation_1-logloss:0.67356
# [3]	validation_0-logloss:0.66726	validation_1-logloss:0.66729
# [2]	validation_0-logloss:0.67328	validation_1-logloss:0.67334
# [2]	validation_0-logloss:0.67330	validation_1-logloss:0.67334
# [4]	validation_0-logloss:0.66111	validation_1-logloss:0.66115
# [3]	validation_0-logloss:0.66724	validation_1-logloss:0.66725
# [4]	validation_0-logloss:0.66112	validation_1-logloss:0.66117
# [3]	validation_0-logloss:0.66724	validation_1-logloss:0.66729
# [4]	validation_0-logloss:0.66111	validation_1-logloss:0.66114
# [5]	validation_0-logloss:0.65506	validation_1-logloss:0.65512
# [2]	validation_0-logloss:0.67329	validation_1-logloss:0.67334
# [5]	validation_0-logloss:0.65508	validation_1-logloss:0.65514
# [3]	validation_0-logloss:0.66693	validation_1-logloss:0.66698
# [3]	validation_0-logloss:0.66693	validation_1-logloss:0.66700
# [6]	validation_0-logloss:0.64912	validation_1-logloss:0.64919
# [4]	validation_0-logloss:0.66105	validation_1-logloss:0.66109
# [5]	validation_0-logloss:0.65507	validation_1-logloss:0.65510
# [3]	validation_0-logloss:0.66695	validation_1-logloss:0.66699
# [4]	validation_0-logloss:0.66108	validation_1-logloss:0.66112
# [6]	validation_0-logloss:0.64915	validation_1-logloss:0.64919
# [5]	validation_0-logloss:0.65504	validation_1-logloss:0.65504
# [6]	validation_0-logloss:0.64915	validation_1-logloss:0.64924
# [7]	validation_0-logloss:0.64333	validation_1-logloss:0.64340
# [7]	validation_0-logloss:0.64335	validation_1-logloss:0.64338
# [5]	validation_0-logloss:0.65503	validation_1-logloss:0.65509
# [4]	validation_0-logloss:0.66066	validation_1-logloss:0.66076
# [4]	validation_0-logloss:0.66072	validation_1-logloss:0.66076
# [4]	validation_0-logloss:0.66070	validation_1-logloss:0.66078
# [7]	validation_0-logloss:0.64336	validation_1-logloss:0.64344
# [6]	validation_0-logloss:0.64910	validation_1-logloss:0.64912
# [8]	validation_0-logloss:0.63761	validation_1-logloss:0.63770
# [8]	validation_0-logloss:0.63767	validation_1-logloss:0.63768
# [6]	validation_0-logloss:0.64909	validation_1-logloss:0.64918
# [5]	validation_0-logloss:0.65459	validation_1-logloss:0.65467
# [8]	validation_0-logloss:0.63765	validation_1-logloss:0.63775
# [5]	validation_0-logloss:0.65454	validation_1-logloss:0.65466
# [5]	validation_0-logloss:0.65457	validation_1-logloss:0.65465
# [7]	validation_0-logloss:0.64326	validation_1-logloss:0.64331
# [9]	validation_0-logloss:0.63205	validation_1-logloss:0.63210
# [9]	validation_0-logloss:0.63201	validation_1-logloss:0.63210
# [7]	validation_0-logloss:0.64326	validation_1-logloss:0.64337
# [9]	validation_0-logloss:0.63206	validation_1-logloss:0.63217
# [6]	validation_0-logloss:0.64859	validation_1-logloss:0.64869
# [8]	validation_0-logloss:0.63757	validation_1-logloss:0.63761
# [8]	validation_0-logloss:0.63757	validation_1-logloss:0.63767
# [10]	validation_0-logloss:0.62658	validation_1-logloss:0.62669
# [6]	validation_0-logloss:0.64859	validation_1-logloss:0.64866
# [10]	validation_0-logloss:0.62657	validation_1-logloss:0.62662
# [10]	validation_0-logloss:0.62653	validation_1-logloss:0.62663
# [11]	validation_0-logloss:0.62120	validation_1-logloss:0.62131
# [9]	validation_0-logloss:0.63197	validation_1-logloss:0.63202
# [9]	validation_0-logloss:0.63195	validation_1-logloss:0.63208
# [6]	validation_0-logloss:0.64853	validation_1-logloss:0.64867
# [7]	validation_0-logloss:0.64270	validation_1-logloss:0.64282
# [11]	validation_0-logloss:0.62119	validation_1-logloss:0.62123
# [12]	validation_0-logloss:0.61588	validation_1-logloss:0.61604
# [7]	validation_0-logloss:0.64270	validation_1-logloss:0.64278
# [10]	validation_0-logloss:0.62646	validation_1-logloss:0.62660
# [10]	validation_0-logloss:0.62644	validation_1-logloss:0.62652
# [11]	validation_0-logloss:0.62114	validation_1-logloss:0.62123
# [7]	validation_0-logloss:0.64264	validation_1-logloss:0.64280
# [11]	validation_0-logloss:0.62107	validation_1-logloss:0.62121
# [13]	validation_0-logloss:0.61070	validation_1-logloss:0.61085
# [8]	validation_0-logloss:0.63691	validation_1-logloss:0.63707
# [12]	validation_0-logloss:0.61576	validation_1-logloss:0.61593
# [11]	validation_0-logloss:0.62105	validation_1-logloss:0.62113
# [12]	validation_0-logloss:0.61589	validation_1-logloss:0.61596
# [12]	validation_0-logloss:0.61585	validation_1-logloss:0.61595
# [13]	validation_0-logloss:0.61055	validation_1-logloss:0.61075
# [8]	validation_0-logloss:0.63691	validation_1-logloss:0.63702
# [14]	validation_0-logloss:0.60560	validation_1-logloss:0.60577
# [14]	validation_0-logloss:0.60547	validation_1-logloss:0.60566
# [12]	validation_0-logloss:0.61577	validation_1-logloss:0.61584
# [9]	validation_0-logloss:0.63127	validation_1-logloss:0.63142
# [8]	validation_0-logloss:0.63689	validation_1-logloss:0.63703
# [13]	validation_0-logloss:0.61066	validation_1-logloss:0.61077
# [13]	validation_0-logloss:0.61072	validation_1-logloss:0.61076
# [15]	validation_0-logloss:0.60045	validation_1-logloss:0.60066
# [13]	validation_0-logloss:0.61056	validation_1-logloss:0.61066
# [15]	validation_0-logloss:0.60061	validation_1-logloss:0.60077
# [9]	validation_0-logloss:0.63126	validation_1-logloss:0.63137
# [14]	validation_0-logloss:0.60546	validation_1-logloss:0.60557
# [16]	validation_0-logloss:0.59551	validation_1-logloss:0.59575
# [9]	validation_0-logloss:0.63120	validation_1-logloss:0.63138
# [14]	validation_0-logloss:0.60556	validation_1-logloss:0.60567
# [16]	validation_0-logloss:0.59571	validation_1-logloss:0.59587
# [14]	validation_0-logloss:0.60562	validation_1-logloss:0.60568
# [15]	validation_0-logloss:0.60045	validation_1-logloss:0.60056
# [10]	validation_0-logloss:0.62568	validation_1-logloss:0.62588
# [16]	validation_0-logloss:0.59554	validation_1-logloss:0.59564
# [17]	validation_0-logloss:0.59069	validation_1-logloss:0.59092
# [10]	validation_0-logloss:0.62571	validation_1-logloss:0.62581
# [10]	validation_0-logloss:0.62564	validation_1-logloss:0.62583
# [17]	validation_0-logloss:0.59085	validation_1-logloss:0.59106
# [15]	validation_0-logloss:0.60058	validation_1-logloss:0.60068
# [17]	validation_0-logloss:0.59072	validation_1-logloss:0.59082
# [15]	validation_0-logloss:0.60055	validation_1-logloss:0.60068
# [18]	validation_0-logloss:0.58596	validation_1-logloss:0.58619
# [18]	validation_0-logloss:0.58612	validation_1-logloss:0.58633
# [11]	validation_0-logloss:0.62025	validation_1-logloss:0.62043
# [11]	validation_0-logloss:0.62019	validation_1-logloss:0.62038
# [11]	validation_0-logloss:0.62022	validation_1-logloss:0.62036
# [16]	validation_0-logloss:0.59567	validation_1-logloss:0.59578
# [18]	validation_0-logloss:0.58594	validation_1-logloss:0.58609
# [16]	validation_0-logloss:0.59561	validation_1-logloss:0.59576
# [19]	validation_0-logloss:0.58149	validation_1-logloss:0.58168
# [19]	validation_0-logloss:0.58129	validation_1-logloss:0.58155
# [12]	validation_0-logloss:0.61487	validation_1-logloss:0.61500
# [17]	validation_0-logloss:0.59079	validation_1-logloss:0.59094
# [19]	validation_0-logloss:0.58129	validation_1-logloss:0.58144
# [12]	validation_0-logloss:0.61489	validation_1-logloss:0.61510
# [17]	validation_0-logloss:0.59086	validation_1-logloss:0.59095
# [12]	validation_0-logloss:0.61481	validation_1-logloss:0.61504
# [20]	validation_0-logloss:0.57691	validation_1-logloss:0.57712
# [20]	validation_0-logloss:0.57669	validation_1-logloss:0.57698
# [18]	validation_0-logloss:0.58605	validation_1-logloss:0.58621
# [20]	validation_0-logloss:0.57670	validation_1-logloss:0.57686
# [13]	validation_0-logloss:0.60963	validation_1-logloss:0.60976
# [21]	validation_0-logloss:0.57220	validation_1-logloss:0.57249
# [18]	validation_0-logloss:0.58610	validation_1-logloss:0.58623
# [21]	validation_0-logloss:0.57241	validation_1-logloss:0.57263
# [13]	validation_0-logloss:0.60955	validation_1-logloss:0.60979
# [13]	validation_0-logloss:0.60961	validation_1-logloss:0.60985
# [19]	validation_0-logloss:0.58138	validation_1-logloss:0.58156
# [21]	validation_0-logloss:0.57220	validation_1-logloss:0.57237
# [22]	validation_0-logloss:0.56779	validation_1-logloss:0.56808
# [19]	validation_0-logloss:0.58146	validation_1-logloss:0.58158
# [22]	validation_0-logloss:0.56799	validation_1-logloss:0.56823
# [14]	validation_0-logloss:0.60440	validation_1-logloss:0.60464
# [14]	validation_0-logloss:0.60446	validation_1-logloss:0.60460
# [14]	validation_0-logloss:0.60446	validation_1-logloss:0.60471
# [22]	validation_0-logloss:0.56777	validation_1-logloss:0.56795
# [20]	validation_0-logloss:0.57688	validation_1-logloss:0.57701
# [23]	validation_0-logloss:0.56367	validation_1-logloss:0.56390
# [20]	validation_0-logloss:0.57683	validation_1-logloss:0.57699
# [21]	validation_0-logloss:0.57238	validation_1-logloss:0.57252
# [23]	validation_0-logloss:0.56345	validation_1-logloss:0.56375
# [23]	validation_0-logloss:0.56343	validation_1-logloss:0.56362
# [21]	validation_0-logloss:0.57231	validation_1-logloss:0.57250
# [15]	validation_0-logloss:0.59939	validation_1-logloss:0.59965
# [24]	validation_0-logloss:0.55938	validation_1-logloss:0.55965
# [22]	validation_0-logloss:0.56796	validation_1-logloss:0.56812
# [15]	validation_0-logloss:0.59936	validation_1-logloss:0.59954
# [15]	validation_0-logloss:0.59933	validation_1-logloss:0.59957
# [22]	validation_0-logloss:0.56790	validation_1-logloss:0.56808
# [24]	validation_0-logloss:0.55915	validation_1-logloss:0.55949
# [23]	validation_0-logloss:0.56356	validation_1-logloss:0.56376
# [24]	validation_0-logloss:0.55917	validation_1-logloss:0.55936
# [25]	validation_0-logloss:0.55520	validation_1-logloss:0.55547
# [23]	validation_0-logloss:0.56363	validation_1-logloss:0.56378
# [16]	validation_0-logloss:0.59439	validation_1-logloss:0.59469
# [24]	validation_0-logloss:0.55931	validation_1-logloss:0.55949
# [25]	validation_0-logloss:0.55498	validation_1-logloss:0.55531
# [25]	validation_0-logloss:0.55497	validation_1-logloss:0.55517
# [16]	validation_0-logloss:0.59439	validation_1-logloss:0.59456
# [24]	validation_0-logloss:0.55938	validation_1-logloss:0.55953
# [26]	validation_0-logloss:0.55109	validation_1-logloss:0.55136
# [16]	validation_0-logloss:0.59432	validation_1-logloss:0.59460
# [25]	validation_0-logloss:0.55510	validation_1-logloss:0.55531
# [26]	validation_0-logloss:0.55086	validation_1-logloss:0.55119
# [27]	validation_0-logloss:0.54705	validation_1-logloss:0.54732
# [26]	validation_0-logloss:0.55084	validation_1-logloss:0.55106
# [25]	validation_0-logloss:0.55517	validation_1-logloss:0.55535
# [28]	validation_0-logloss:0.54305	validation_1-logloss:0.54335
# [17]	validation_0-logloss:0.58952	validation_1-logloss:0.58983
# [26]	validation_0-logloss:0.55097	validation_1-logloss:0.55119
# [27]	validation_0-logloss:0.54682	validation_1-logloss:0.54715
# [26]	validation_0-logloss:0.55106	validation_1-logloss:0.55123
# [27]	validation_0-logloss:0.54679	validation_1-logloss:0.54701
# [17]	validation_0-logloss:0.58952	validation_1-logloss:0.58968
# [27]	validation_0-logloss:0.54693	validation_1-logloss:0.54716
# [17]	validation_0-logloss:0.58945	validation_1-logloss:0.58972
# [27]	validation_0-logloss:0.54701	validation_1-logloss:0.54719
# [29]	validation_0-logloss:0.53914	validation_1-logloss:0.53946
# [28]	validation_0-logloss:0.54281	validation_1-logloss:0.54318
# [28]	validation_0-logloss:0.54282	validation_1-logloss:0.54303
# [28]	validation_0-logloss:0.54305	validation_1-logloss:0.54322
# [18]	validation_0-logloss:0.58469	validation_1-logloss:0.58489
# [29]	validation_0-logloss:0.53889	validation_1-logloss:0.53928
# [28]	validation_0-logloss:0.54296	validation_1-logloss:0.54318
# [18]	validation_0-logloss:0.58470	validation_1-logloss:0.58503
# [29]	validation_0-logloss:0.53890	validation_1-logloss:0.53913
# [18]	validation_0-logloss:0.58462	validation_1-logloss:0.58492
# [19]	validation_0-logloss:0.58000	validation_1-logloss:0.58018
# [29]	validation_0-logloss:0.53914	validation_1-logloss:0.53932
# [30]	validation_0-logloss:0.53529	validation_1-logloss:0.53562
# [30]	validation_0-logloss:0.53505	validation_1-logloss:0.53543
# [30]	validation_0-logloss:0.53505	validation_1-logloss:0.53529
# [29]	validation_0-logloss:0.53904	validation_1-logloss:0.53927
# [30]	validation_0-logloss:0.53528	validation_1-logloss:0.53548
# [31]	validation_0-logloss:0.53153	validation_1-logloss:0.53184
# [20]	validation_0-logloss:0.57536	validation_1-logloss:0.57555
# [19]	validation_0-logloss:0.57997	validation_1-logloss:0.58033
# [19]	validation_0-logloss:0.57992	validation_1-logloss:0.58022
# [30]	validation_0-logloss:0.53519	validation_1-logloss:0.53543
# [31]	validation_0-logloss:0.53124	validation_1-logloss:0.53151
# [31]	validation_0-logloss:0.53127	validation_1-logloss:0.53166
# [21]	validation_0-logloss:0.57080	validation_1-logloss:0.57101
# [32]	validation_0-logloss:0.52779	validation_1-logloss:0.52813
# [31]	validation_0-logloss:0.53149	validation_1-logloss:0.53170
# [31]	validation_0-logloss:0.53138	validation_1-logloss:0.53166
# [20]	validation_0-logloss:0.57536	validation_1-logloss:0.57570
# [32]	validation_0-logloss:0.52755	validation_1-logloss:0.52795
# [20]	validation_0-logloss:0.57528	validation_1-logloss:0.57559
# [32]	validation_0-logloss:0.52754	validation_1-logloss:0.52780
# [32]	validation_0-logloss:0.52770	validation_1-logloss:0.52794
# [22]	validation_0-logloss:0.56633	validation_1-logloss:0.56653
# [33]	validation_0-logloss:0.52414	validation_1-logloss:0.52449
# [33]	validation_0-logloss:0.52404	validation_1-logloss:0.52429
# [32]	validation_0-logloss:0.52779	validation_1-logloss:0.52799
# [33]	validation_0-logloss:0.52389	validation_1-logloss:0.52431
# [21]	validation_0-logloss:0.57081	validation_1-logloss:0.57117
# [33]	validation_0-logloss:0.52388	validation_1-logloss:0.52415
# [21]	validation_0-logloss:0.57072	validation_1-logloss:0.57105
# [34]	validation_0-logloss:0.52042	validation_1-logloss:0.52071
# [33]	validation_0-logloss:0.52414	validation_1-logloss:0.52434
# [34]	validation_0-logloss:0.52053	validation_1-logloss:0.52090
# [23]	validation_0-logloss:0.56193	validation_1-logloss:0.56215
# [34]	validation_0-logloss:0.52028	validation_1-logloss:0.52072
# [22]	validation_0-logloss:0.56624	validation_1-logloss:0.56658
# [35]	validation_0-logloss:0.51690	validation_1-logloss:0.51718
# [34]	validation_0-logloss:0.52026	validation_1-logloss:0.52056
# [22]	validation_0-logloss:0.56631	validation_1-logloss:0.56670
# [34]	validation_0-logloss:0.52053	validation_1-logloss:0.52076
# [35]	validation_0-logloss:0.51674	validation_1-logloss:0.51719
# [35]	validation_0-logloss:0.51702	validation_1-logloss:0.51738
# [24]	validation_0-logloss:0.55759	validation_1-logloss:0.55783
# [36]	validation_0-logloss:0.51340	validation_1-logloss:0.51371
# [36]	validation_0-logloss:0.51326	validation_1-logloss:0.51372
# [35]	validation_0-logloss:0.51698	validation_1-logloss:0.51723
# [23]	validation_0-logloss:0.56185	validation_1-logloss:0.56220
# [35]	validation_0-logloss:0.51673	validation_1-logloss:0.51703
# [23]	validation_0-logloss:0.56192	validation_1-logloss:0.56233
# [36]	validation_0-logloss:0.51352	validation_1-logloss:0.51391
# [37]	validation_0-logloss:0.51000	validation_1-logloss:0.51030
# [37]	validation_0-logloss:0.50983	validation_1-logloss:0.51030
# [25]	validation_0-logloss:0.55334	validation_1-logloss:0.55359
# [36]	validation_0-logloss:0.51352	validation_1-logloss:0.51376
# [36]	validation_0-logloss:0.51324	validation_1-logloss:0.51356
# [24]	validation_0-logloss:0.55751	validation_1-logloss:0.55788
# [37]	validation_0-logloss:0.51013	validation_1-logloss:0.51050
# [24]	validation_0-logloss:0.55759	validation_1-logloss:0.55802
# [38]	validation_0-logloss:0.50663	validation_1-logloss:0.50694
# [38]	validation_0-logloss:0.50646	validation_1-logloss:0.50695
# [37]	validation_0-logloss:0.51009	validation_1-logloss:0.51035
# [37]	validation_0-logloss:0.50983	validation_1-logloss:0.51014
# [38]	validation_0-logloss:0.50675	validation_1-logloss:0.50714
# [25]	validation_0-logloss:0.55325	validation_1-logloss:0.55366
# [26]	validation_0-logloss:0.54917	validation_1-logloss:0.54942
# [39]	validation_0-logloss:0.50316	validation_1-logloss:0.50365
# [25]	validation_0-logloss:0.55336	validation_1-logloss:0.55378
# [39]	validation_0-logloss:0.50330	validation_1-logloss:0.50363
# [38]	validation_0-logloss:0.50672	validation_1-logloss:0.50699
# [39]	validation_0-logloss:0.50342	validation_1-logloss:0.50384
# [38]	validation_0-logloss:0.50647	validation_1-logloss:0.50678
# [26]	validation_0-logloss:0.54908	validation_1-logloss:0.54949
# [40]	validation_0-logloss:0.49990	validation_1-logloss:0.50040
# [39]	validation_0-logloss:0.50343	validation_1-logloss:0.50369
# [27]	validation_0-logloss:0.54506	validation_1-logloss:0.54533
# [40]	validation_0-logloss:0.50017	validation_1-logloss:0.50059
# [40]	validation_0-logloss:0.50005	validation_1-logloss:0.50039
# [26]	validation_0-logloss:0.54919	validation_1-logloss:0.54962
# [27]	validation_0-logloss:0.54499	validation_1-logloss:0.54540
# [39]	validation_0-logloss:0.50314	validation_1-logloss:0.50347
# [40]	validation_0-logloss:0.50016	validation_1-logloss:0.50044
# [41]	validation_0-logloss:0.49669	validation_1-logloss:0.49721
# [28]	validation_0-logloss:0.54105	validation_1-logloss:0.54131
# [41]	validation_0-logloss:0.49698	validation_1-logloss:0.49740
# [41]	validation_0-logloss:0.49697	validation_1-logloss:0.49724
# [28]	validation_0-logloss:0.54093	validation_1-logloss:0.54137
# [42]	validation_0-logloss:0.49382	validation_1-logloss:0.49410
# [41]	validation_0-logloss:0.49685	validation_1-logloss:0.49719
# [40]	validation_0-logloss:0.49988	validation_1-logloss:0.50023
# [42]	validation_0-logloss:0.49354	validation_1-logloss:0.49407
# [27]	validation_0-logloss:0.54506	validation_1-logloss:0.54554
# [29]	validation_0-logloss:0.53699	validation_1-logloss:0.53742
# [43]	validation_0-logloss:0.49044	validation_1-logloss:0.49097
# [42]	validation_0-logloss:0.49382	validation_1-logloss:0.49425
# [29]	validation_0-logloss:0.53707	validation_1-logloss:0.53735
# [43]	validation_0-logloss:0.49070	validation_1-logloss:0.49101
# [42]	validation_0-logloss:0.49369	validation_1-logloss:0.49404
# [41]	validation_0-logloss:0.49669	validation_1-logloss:0.49703
# [28]	validation_0-logloss:0.54105	validation_1-logloss:0.54152
# [30]	validation_0-logloss:0.53307	validation_1-logloss:0.53353
# [44]	validation_0-logloss:0.48738	validation_1-logloss:0.48793
# [43]	validation_0-logloss:0.49073	validation_1-logloss:0.49116
# [44]	validation_0-logloss:0.48766	validation_1-logloss:0.48797
# [30]	validation_0-logloss:0.53318	validation_1-logloss:0.53345
# [43]	validation_0-logloss:0.49059	validation_1-logloss:0.49095
# [42]	validation_0-logloss:0.49352	validation_1-logloss:0.49389
# [45]	validation_0-logloss:0.48439	validation_1-logloss:0.48494
# [44]	validation_0-logloss:0.48767	validation_1-logloss:0.48812
# [29]	validation_0-logloss:0.53708	validation_1-logloss:0.53756
# [31]	validation_0-logloss:0.52924	validation_1-logloss:0.52971
# [45]	validation_0-logloss:0.48465	validation_1-logloss:0.48498
# [44]	validation_0-logloss:0.48754	validation_1-logloss:0.48790
# [43]	validation_0-logloss:0.49044	validation_1-logloss:0.49079
# [46]	validation_0-logloss:0.48142	validation_1-logloss:0.48200
# [31]	validation_0-logloss:0.52932	validation_1-logloss:0.52963
# [45]	validation_0-logloss:0.48468	validation_1-logloss:0.48513
# [46]	validation_0-logloss:0.48171	validation_1-logloss:0.48203
# [30]	validation_0-logloss:0.53316	validation_1-logloss:0.53368
# [45]	validation_0-logloss:0.48454	validation_1-logloss:0.48491
# [32]	validation_0-logloss:0.52556	validation_1-logloss:0.52586
# [32]	validation_0-logloss:0.52546	validation_1-logloss:0.52595
# [44]	validation_0-logloss:0.48737	validation_1-logloss:0.48774
# [47]	validation_0-logloss:0.47853	validation_1-logloss:0.47910
# [46]	validation_0-logloss:0.48171	validation_1-logloss:0.48218
# [47]	validation_0-logloss:0.47879	validation_1-logloss:0.47913
# [33]	validation_0-logloss:0.52176	validation_1-logloss:0.52225
# [46]	validation_0-logloss:0.48158	validation_1-logloss:0.48197
# [33]	validation_0-logloss:0.52184	validation_1-logloss:0.52216
# [31]	validation_0-logloss:0.52934	validation_1-logloss:0.52986
# [45]	validation_0-logloss:0.48438	validation_1-logloss:0.48475
# [47]	validation_0-logloss:0.47881	validation_1-logloss:0.47929
# [48]	validation_0-logloss:0.47566	validation_1-logloss:0.47625
# [32]	validation_0-logloss:0.52556	validation_1-logloss:0.52609
# [34]	validation_0-logloss:0.51809	validation_1-logloss:0.51861
# [48]	validation_0-logloss:0.47594	validation_1-logloss:0.47628
# [47]	validation_0-logloss:0.47868	validation_1-logloss:0.47907
# [33]	validation_0-logloss:0.52186	validation_1-logloss:0.52241
# [48]	validation_0-logloss:0.47595	validation_1-logloss:0.47643
# [46]	validation_0-logloss:0.48141	validation_1-logloss:0.48180
# [34]	validation_0-logloss:0.51821	validation_1-logloss:0.51852
# [49]	validation_0-logloss:0.47285	validation_1-logloss:0.47344
# [35]	validation_0-logloss:0.51450	validation_1-logloss:0.51504
# [49]	validation_0-logloss:0.47312	validation_1-logloss:0.47347
# [34]	validation_0-logloss:0.51819	validation_1-logloss:0.51877
# [48]	validation_0-logloss:0.47581	validation_1-logloss:0.47622
# [49]	validation_0-logloss:0.47313	validation_1-logloss:0.47362
# [36]	validation_0-logloss:0.51098	validation_1-logloss:0.51153
# [47]	validation_0-logloss:0.47851	validation_1-logloss:0.47890
# [50]	validation_0-logloss:0.47008	validation_1-logloss:0.47068
# [35]	validation_0-logloss:0.51462	validation_1-logloss:0.51494
# [50]	validation_0-logloss:0.47037	validation_1-logloss:0.47071
# [37]	validation_0-logloss:0.50750	validation_1-logloss:0.50807
# [35]	validation_0-logloss:0.51462	validation_1-logloss:0.51519
# [49]	validation_0-logloss:0.47299	validation_1-logloss:0.47340
# [50]	validation_0-logloss:0.47037	validation_1-logloss:0.47086
# [51]	validation_0-logloss:0.46734	validation_1-logloss:0.46796
# [48]	validation_0-logloss:0.47564	validation_1-logloss:0.47605
# [36]	validation_0-logloss:0.51108	validation_1-logloss:0.51142
# [38]	validation_0-logloss:0.50408	validation_1-logloss:0.50467
# [51]	validation_0-logloss:0.46762	validation_1-logloss:0.46799
# [50]	validation_0-logloss:0.47023	validation_1-logloss:0.47064
# [52]	validation_0-logloss:0.46465	validation_1-logloss:0.46529
# [51]	validation_0-logloss:0.46763	validation_1-logloss:0.46815
# [36]	validation_0-logloss:0.51109	validation_1-logloss:0.51168
# [49]	validation_0-logloss:0.47283	validation_1-logloss:0.47323
# [51]	validation_0-logloss:0.46751	validation_1-logloss:0.46792
# [52]	validation_0-logloss:0.46494	validation_1-logloss:0.46531
# [37]	validation_0-logloss:0.50763	validation_1-logloss:0.50794
# [53]	validation_0-logloss:0.46203	validation_1-logloss:0.46266
# [50]	validation_0-logloss:0.47005	validation_1-logloss:0.47048
# [39]	validation_0-logloss:0.50074	validation_1-logloss:0.50132
# [53]	validation_0-logloss:0.46231	validation_1-logloss:0.46268
# [52]	validation_0-logloss:0.46494	validation_1-logloss:0.46547
# [37]	validation_0-logloss:0.50761	validation_1-logloss:0.50823
# [52]	validation_0-logloss:0.46481	validation_1-logloss:0.46524
# [54]	validation_0-logloss:0.45943	validation_1-logloss:0.46006
# [38]	validation_0-logloss:0.50421	validation_1-logloss:0.50453
# [51]	validation_0-logloss:0.46733	validation_1-logloss:0.46775
# [53]	validation_0-logloss:0.46219	validation_1-logloss:0.46261
# [40]	validation_0-logloss:0.49743	validation_1-logloss:0.49803
# [53]	validation_0-logloss:0.46231	validation_1-logloss:0.46284
# [54]	validation_0-logloss:0.45971	validation_1-logloss:0.46009
# [55]	validation_0-logloss:0.45685	validation_1-logloss:0.45751
# [54]	validation_0-logloss:0.45959	validation_1-logloss:0.46002
# [41]	validation_0-logloss:0.49416	validation_1-logloss:0.49479
# [52]	validation_0-logloss:0.46464	validation_1-logloss:0.46508
# [38]	validation_0-logloss:0.50421	validation_1-logloss:0.50482
# [55]	validation_0-logloss:0.45714	validation_1-logloss:0.45754
# [54]	validation_0-logloss:0.45971	validation_1-logloss:0.46024
# [39]	validation_0-logloss:0.50084	validation_1-logloss:0.50119
# [56]	validation_0-logloss:0.45434	validation_1-logloss:0.45500
# [55]	validation_0-logloss:0.45703	validation_1-logloss:0.45747
# [42]	validation_0-logloss:0.49097	validation_1-logloss:0.49160
# [56]	validation_0-logloss:0.45464	validation_1-logloss:0.45502
# [53]	validation_0-logloss:0.46198	validation_1-logloss:0.46245
# [39]	validation_0-logloss:0.50084	validation_1-logloss:0.50148
# [56]	validation_0-logloss:0.45450	validation_1-logloss:0.45494
# [55]	validation_0-logloss:0.45713	validation_1-logloss:0.45769
# [57]	validation_0-logloss:0.45203	validation_1-logloss:0.45247
# [43]	validation_0-logloss:0.48783	validation_1-logloss:0.48847
# [57]	validation_0-logloss:0.45215	validation_1-logloss:0.45255
# [57]	validation_0-logloss:0.45184	validation_1-logloss:0.45252
# [40]	validation_0-logloss:0.49753	validation_1-logloss:0.49789
# [44]	validation_0-logloss:0.48472	validation_1-logloss:0.48538
# [58]	validation_0-logloss:0.44958	validation_1-logloss:0.45003
# [40]	validation_0-logloss:0.49754	validation_1-logloss:0.49819
# [54]	validation_0-logloss:0.45938	validation_1-logloss:0.45985
# [58]	validation_0-logloss:0.44971	validation_1-logloss:0.45012
# [56]	validation_0-logloss:0.45462	validation_1-logloss:0.45518
# [58]	validation_0-logloss:0.44942	validation_1-logloss:0.45009
# [59]	validation_0-logloss:0.44717	validation_1-logloss:0.44763
# [55]	validation_0-logloss:0.45684	validation_1-logloss:0.45729
# [59]	validation_0-logloss:0.44731	validation_1-logloss:0.44772
# [45]	validation_0-logloss:0.48168	validation_1-logloss:0.48234
# [57]	validation_0-logloss:0.45213	validation_1-logloss:0.45271
# [41]	validation_0-logloss:0.49429	validation_1-logloss:0.49463
# [56]	validation_0-logloss:0.45430	validation_1-logloss:0.45478
# [59]	validation_0-logloss:0.44701	validation_1-logloss:0.44769
# [41]	validation_0-logloss:0.49430	validation_1-logloss:0.49495
# [60]	validation_0-logloss:0.44481	validation_1-logloss:0.44528
# [57]	validation_0-logloss:0.45184	validation_1-logloss:0.45231
# [58]	validation_0-logloss:0.44971	validation_1-logloss:0.45027
# [60]	validation_0-logloss:0.44464	validation_1-logloss:0.44533
# [46]	validation_0-logloss:0.47868	validation_1-logloss:0.47936
# [60]	validation_0-logloss:0.44493	validation_1-logloss:0.44536
# [58]	validation_0-logloss:0.44938	validation_1-logloss:0.44987
# [61]	validation_0-logloss:0.44247	validation_1-logloss:0.44295
# [42]	validation_0-logloss:0.49109	validation_1-logloss:0.49177
# [61]	validation_0-logloss:0.44261	validation_1-logloss:0.44304
# [42]	validation_0-logloss:0.49110	validation_1-logloss:0.49142
# [59]	validation_0-logloss:0.44730	validation_1-logloss:0.44788
# [61]	validation_0-logloss:0.44230	validation_1-logloss:0.44301
# [59]	validation_0-logloss:0.44697	validation_1-logloss:0.44748
# [62]	validation_0-logloss:0.44031	validation_1-logloss:0.44075
# [47]	validation_0-logloss:0.47573	validation_1-logloss:0.47642
# [62]	validation_0-logloss:0.44017	validation_1-logloss:0.44065
# [62]	validation_0-logloss:0.44001	validation_1-logloss:0.44072
# [43]	validation_0-logloss:0.48795	validation_1-logloss:0.48863
# [60]	validation_0-logloss:0.44492	validation_1-logloss:0.44552
# [63]	validation_0-logloss:0.43804	validation_1-logloss:0.43850
# [60]	validation_0-logloss:0.44461	validation_1-logloss:0.44511
# [43]	validation_0-logloss:0.48796	validation_1-logloss:0.48828
# [48]	validation_0-logloss:0.47282	validation_1-logloss:0.47352
# [63]	validation_0-logloss:0.43793	validation_1-logloss:0.43840
# [61]	validation_0-logloss:0.44260	validation_1-logloss:0.44320
# [63]	validation_0-logloss:0.43774	validation_1-logloss:0.43847
# [64]	validation_0-logloss:0.43582	validation_1-logloss:0.43628
# [44]	validation_0-logloss:0.48485	validation_1-logloss:0.48519
# [62]	validation_0-logloss:0.44030	validation_1-logloss:0.44091
# [44]	validation_0-logloss:0.48485	validation_1-logloss:0.48555
# [64]	validation_0-logloss:0.43571	validation_1-logloss:0.43618
# [45]	validation_0-logloss:0.48179	validation_1-logloss:0.48214
# [65]	validation_0-logloss:0.43364	validation_1-logloss:0.43410
# [64]	validation_0-logloss:0.43551	validation_1-logloss:0.43625
# [61]	validation_0-logloss:0.44227	validation_1-logloss:0.44279
# [49]	validation_0-logloss:0.46995	validation_1-logloss:0.47067
# [65]	validation_0-logloss:0.43332	validation_1-logloss:0.43407
# [63]	validation_0-logloss:0.43805	validation_1-logloss:0.43866
# [65]	validation_0-logloss:0.43352	validation_1-logloss:0.43399
# [66]	validation_0-logloss:0.43147	validation_1-logloss:0.43195
# [62]	validation_0-logloss:0.43999	validation_1-logloss:0.44050
# [66]	validation_0-logloss:0.43117	validation_1-logloss:0.43192
# [46]	validation_0-logloss:0.47880	validation_1-logloss:0.47916
# [64]	validation_0-logloss:0.43581	validation_1-logloss:0.43645
# [45]	validation_0-logloss:0.48180	validation_1-logloss:0.48251
# [67]	validation_0-logloss:0.42905	validation_1-logloss:0.42980
# [66]	validation_0-logloss:0.43136	validation_1-logloss:0.43182
# [67]	validation_0-logloss:0.42935	validation_1-logloss:0.42984
# [65]	validation_0-logloss:0.43362	validation_1-logloss:0.43426
# [50]	validation_0-logloss:0.46713	validation_1-logloss:0.46786
# [63]	validation_0-logloss:0.43772	validation_1-logloss:0.43825
# [67]	validation_0-logloss:0.42923	validation_1-logloss:0.42970
# [68]	validation_0-logloss:0.42694	validation_1-logloss:0.42771
# [68]	validation_0-logloss:0.42725	validation_1-logloss:0.42775
# [47]	validation_0-logloss:0.47584	validation_1-logloss:0.47621
# [66]	validation_0-logloss:0.43147	validation_1-logloss:0.43211
# [46]	validation_0-logloss:0.47879	validation_1-logloss:0.47953
# [64]	validation_0-logloss:0.43550	validation_1-logloss:0.43604
# [68]	validation_0-logloss:0.42713	validation_1-logloss:0.42762
# [69]	validation_0-logloss:0.42520	validation_1-logloss:0.42570
# [69]	validation_0-logloss:0.42489	validation_1-logloss:0.42567
# [51]	validation_0-logloss:0.46436	validation_1-logloss:0.46510
# [67]	validation_0-logloss:0.42935	validation_1-logloss:0.43000
# [48]	validation_0-logloss:0.47293	validation_1-logloss:0.47331
# [69]	validation_0-logloss:0.42508	validation_1-logloss:0.42557
# [70]	validation_0-logloss:0.42317	validation_1-logloss:0.42368
# [65]	validation_0-logloss:0.43330	validation_1-logloss:0.43385
# [70]	validation_0-logloss:0.42287	validation_1-logloss:0.42364
# [68]	validation_0-logloss:0.42724	validation_1-logloss:0.42791
# [47]	validation_0-logloss:0.47584	validation_1-logloss:0.47658
# [52]	validation_0-logloss:0.46163	validation_1-logloss:0.46238
# [70]	validation_0-logloss:0.42305	validation_1-logloss:0.42353
# [71]	validation_0-logloss:0.42118	validation_1-logloss:0.42169
# [69]	validation_0-logloss:0.42520	validation_1-logloss:0.42586
# [71]	validation_0-logloss:0.42087	validation_1-logloss:0.42165
# [66]	validation_0-logloss:0.43115	validation_1-logloss:0.43170
# [53]	validation_0-logloss:0.45893	validation_1-logloss:0.45970
# [71]	validation_0-logloss:0.42105	validation_1-logloss:0.42154
# [49]	validation_0-logloss:0.47007	validation_1-logloss:0.47043
# [72]	validation_0-logloss:0.41921	validation_1-logloss:0.41973
# [48]	validation_0-logloss:0.47294	validation_1-logloss:0.47369
# [70]	validation_0-logloss:0.42316	validation_1-logloss:0.42384
# [72]	validation_0-logloss:0.41889	validation_1-logloss:0.41970
# [73]	validation_0-logloss:0.41728	validation_1-logloss:0.41779
# [67]	validation_0-logloss:0.42903	validation_1-logloss:0.42958
# [72]	validation_0-logloss:0.41909	validation_1-logloss:0.41958
# [54]	validation_0-logloss:0.45630	validation_1-logloss:0.45706
# [71]	validation_0-logloss:0.42117	validation_1-logloss:0.42185
# [73]	validation_0-logloss:0.41695	validation_1-logloss:0.41776
# [73]	validation_0-logloss:0.41715	validation_1-logloss:0.41764
# [74]	validation_0-logloss:0.41536	validation_1-logloss:0.41590
# [49]	validation_0-logloss:0.47009	validation_1-logloss:0.47084
# [50]	validation_0-logloss:0.46725	validation_1-logloss:0.46763
# [55]	validation_0-logloss:0.45370	validation_1-logloss:0.45448
# [68]	validation_0-logloss:0.42693	validation_1-logloss:0.42750
# [74]	validation_0-logloss:0.41523	validation_1-logloss:0.41573
# [75]	validation_0-logloss:0.41349	validation_1-logloss:0.41402
# [74]	validation_0-logloss:0.41505	validation_1-logloss:0.41586
# [72]	validation_0-logloss:0.41919	validation_1-logloss:0.41989
# [76]	validation_0-logloss:0.41163	validation_1-logloss:0.41218
# [75]	validation_0-logloss:0.41316	validation_1-logloss:0.41398
# [75]	validation_0-logloss:0.41336	validation_1-logloss:0.41385
# [56]	validation_0-logloss:0.45113	validation_1-logloss:0.45191
# [50]	validation_0-logloss:0.46728	validation_1-logloss:0.46805
# [69]	validation_0-logloss:0.42489	validation_1-logloss:0.42545
# [73]	validation_0-logloss:0.41725	validation_1-logloss:0.41796
# [51]	validation_0-logloss:0.46451	validation_1-logloss:0.46485
# [76]	validation_0-logloss:0.41132	validation_1-logloss:0.41214
# [77]	validation_0-logloss:0.40980	validation_1-logloss:0.41036
# [76]	validation_0-logloss:0.41151	validation_1-logloss:0.41201
# [57]	validation_0-logloss:0.44862	validation_1-logloss:0.44940
# [70]	validation_0-logloss:0.42285	validation_1-logloss:0.42343
# [74]	validation_0-logloss:0.41534	validation_1-logloss:0.41605
# [78]	validation_0-logloss:0.40802	validation_1-logloss:0.40857
# [51]	validation_0-logloss:0.46449	validation_1-logloss:0.46528
# [77]	validation_0-logloss:0.40949	validation_1-logloss:0.41033
# [77]	validation_0-logloss:0.40968	validation_1-logloss:0.41019
# [79]	validation_0-logloss:0.40624	validation_1-logloss:0.40681
# [52]	validation_0-logloss:0.46177	validation_1-logloss:0.46213
# [80]	validation_0-logloss:0.40450	validation_1-logloss:0.40508
# [75]	validation_0-logloss:0.41347	validation_1-logloss:0.41418
# [78]	validation_0-logloss:0.40789	validation_1-logloss:0.40838
# [58]	validation_0-logloss:0.44612	validation_1-logloss:0.44691
# [71]	validation_0-logloss:0.42085	validation_1-logloss:0.42144
# [81]	validation_0-logloss:0.40279	validation_1-logloss:0.40336
# [78]	validation_0-logloss:0.40769	validation_1-logloss:0.40853
# [52]	validation_0-logloss:0.46176	validation_1-logloss:0.46257
# [76]	validation_0-logloss:0.41162	validation_1-logloss:0.41234
# [82]	validation_0-logloss:0.40109	validation_1-logloss:0.40168
# [79]	validation_0-logloss:0.40611	validation_1-logloss:0.40662
# [53]	validation_0-logloss:0.45908	validation_1-logloss:0.45945
# [72]	validation_0-logloss:0.41888	validation_1-logloss:0.41947
# [79]	validation_0-logloss:0.40592	validation_1-logloss:0.40677
# [59]	validation_0-logloss:0.44367	validation_1-logloss:0.44448
# [77]	validation_0-logloss:0.40980	validation_1-logloss:0.41052
# [83]	validation_0-logloss:0.39942	validation_1-logloss:0.40003
# [80]	validation_0-logloss:0.40436	validation_1-logloss:0.40488
# [73]	validation_0-logloss:0.41695	validation_1-logloss:0.41754
# [53]	validation_0-logloss:0.45910	validation_1-logloss:0.45989
# [54]	validation_0-logloss:0.45643	validation_1-logloss:0.45682
# [80]	validation_0-logloss:0.40418	validation_1-logloss:0.40504
# [60]	validation_0-logloss:0.44126	validation_1-logloss:0.44208
# [84]	validation_0-logloss:0.39778	validation_1-logloss:0.39839
# [78]	validation_0-logloss:0.40800	validation_1-logloss:0.40874
# [81]	validation_0-logloss:0.40265	validation_1-logloss:0.40317
# [74]	validation_0-logloss:0.41504	validation_1-logloss:0.41565
# [81]	validation_0-logloss:0.40245	validation_1-logloss:0.40333
# [54]	validation_0-logloss:0.45645	validation_1-logloss:0.45726
# [55]	validation_0-logloss:0.45382	validation_1-logloss:0.45422
# [85]	validation_0-logloss:0.39617	validation_1-logloss:0.39678
# [79]	validation_0-logloss:0.40623	validation_1-logloss:0.40698
# [82]	validation_0-logloss:0.40096	validation_1-logloss:0.40149
# [75]	validation_0-logloss:0.41315	validation_1-logloss:0.41377
# [61]	validation_0-logloss:0.43889	validation_1-logloss:0.43971
# [76]	validation_0-logloss:0.41129	validation_1-logloss:0.41193
# [55]	validation_0-logloss:0.45384	validation_1-logloss:0.45467
# [86]	validation_0-logloss:0.39457	validation_1-logloss:0.39520
# [82]	validation_0-logloss:0.40077	validation_1-logloss:0.40165
# [83]	validation_0-logloss:0.39931	validation_1-logloss:0.39981
# [80]	validation_0-logloss:0.40447	validation_1-logloss:0.40524
# [77]	validation_0-logloss:0.40948	validation_1-logloss:0.41011
# [56]	validation_0-logloss:0.45125	validation_1-logloss:0.45165
# [62]	validation_0-logloss:0.43655	validation_1-logloss:0.43739
# [56]	validation_0-logloss:0.45129	validation_1-logloss:0.45212
# [81]	validation_0-logloss:0.40277	validation_1-logloss:0.40353
# [87]	validation_0-logloss:0.39301	validation_1-logloss:0.39364
# [84]	validation_0-logloss:0.39766	validation_1-logloss:0.39818
# [83]	validation_0-logloss:0.39911	validation_1-logloss:0.39999
# [57]	validation_0-logloss:0.44877	validation_1-logloss:0.44960
# [82]	validation_0-logloss:0.40107	validation_1-logloss:0.40186
# [63]	validation_0-logloss:0.43426	validation_1-logloss:0.43510
# [88]	validation_0-logloss:0.39146	validation_1-logloss:0.39210
# [78]	validation_0-logloss:0.40768	validation_1-logloss:0.40833
# [58]	validation_0-logloss:0.44627	validation_1-logloss:0.44714
# [85]	validation_0-logloss:0.39605	validation_1-logloss:0.39654
# [84]	validation_0-logloss:0.39747	validation_1-logloss:0.39836
# [57]	validation_0-logloss:0.44873	validation_1-logloss:0.44913
# [59]	validation_0-logloss:0.44382	validation_1-logloss:0.44470
# [83]	validation_0-logloss:0.39940	validation_1-logloss:0.40020
# [89]	validation_0-logloss:0.38993	validation_1-logloss:0.39059
# [79]	validation_0-logloss:0.40591	validation_1-logloss:0.40656
# [64]	validation_0-logloss:0.43197	validation_1-logloss:0.43284
# [85]	validation_0-logloss:0.39584	validation_1-logloss:0.39672
# [86]	validation_0-logloss:0.39445	validation_1-logloss:0.39496
# [90]	validation_0-logloss:0.38844	validation_1-logloss:0.38909
# [84]	validation_0-logloss:0.39776	validation_1-logloss:0.39856
# [60]	validation_0-logloss:0.44143	validation_1-logloss:0.44229
# [58]	validation_0-logloss:0.44626	validation_1-logloss:0.44664
# [80]	validation_0-logloss:0.40416	validation_1-logloss:0.40483
# [86]	validation_0-logloss:0.39426	validation_1-logloss:0.39514
# [87]	validation_0-logloss:0.39289	validation_1-logloss:0.39340
# [91]	validation_0-logloss:0.38697	validation_1-logloss:0.38762
# [61]	validation_0-logloss:0.43904	validation_1-logloss:0.43993
# [65]	validation_0-logloss:0.42975	validation_1-logloss:0.43061
# [85]	validation_0-logloss:0.39614	validation_1-logloss:0.39695
# [81]	validation_0-logloss:0.40245	validation_1-logloss:0.40312
# [88]	validation_0-logloss:0.39133	validation_1-logloss:0.39186
# [92]	validation_0-logloss:0.38551	validation_1-logloss:0.38618
# [87]	validation_0-logloss:0.39268	validation_1-logloss:0.39357
# [59]	validation_0-logloss:0.44382	validation_1-logloss:0.44421
# [62]	validation_0-logloss:0.43671	validation_1-logloss:0.43760
# [88]	validation_0-logloss:0.39115	validation_1-logloss:0.39204
# [82]	validation_0-logloss:0.40076	validation_1-logloss:0.40143
# [66]	validation_0-logloss:0.42754	validation_1-logloss:0.42842
# [86]	validation_0-logloss:0.39456	validation_1-logloss:0.39537
# [89]	validation_0-logloss:0.38981	validation_1-logloss:0.39035
# [93]	validation_0-logloss:0.38406	validation_1-logloss:0.38475
# [60]	validation_0-logloss:0.44139	validation_1-logloss:0.44178
# [89]	validation_0-logloss:0.38961	validation_1-logloss:0.39052
# [87]	validation_0-logloss:0.39299	validation_1-logloss:0.39381
# [90]	validation_0-logloss:0.38831	validation_1-logloss:0.38883
# [83]	validation_0-logloss:0.39909	validation_1-logloss:0.39978
# [67]	validation_0-logloss:0.42538	validation_1-logloss:0.42626
# [63]	validation_0-logloss:0.43441	validation_1-logloss:0.43530
# [94]	validation_0-logloss:0.38266	validation_1-logloss:0.38334
# [88]	validation_0-logloss:0.39144	validation_1-logloss:0.39228
# [90]	validation_0-logloss:0.38812	validation_1-logloss:0.38903
# [61]	validation_0-logloss:0.43903	validation_1-logloss:0.43943
# [91]	validation_0-logloss:0.38683	validation_1-logloss:0.38736
# [84]	validation_0-logloss:0.39745	validation_1-logloss:0.39815
# [89]	validation_0-logloss:0.38993	validation_1-logloss:0.39076
# [68]	validation_0-logloss:0.42325	validation_1-logloss:0.42413
# [64]	validation_0-logloss:0.43215	validation_1-logloss:0.43303
# [95]	validation_0-logloss:0.38126	validation_1-logloss:0.38196
# [92]	validation_0-logloss:0.38538	validation_1-logloss:0.38591
# [62]	validation_0-logloss:0.43668	validation_1-logloss:0.43709
# [91]	validation_0-logloss:0.38663	validation_1-logloss:0.38756
# [85]	validation_0-logloss:0.39583	validation_1-logloss:0.39654
# [90]	validation_0-logloss:0.38842	validation_1-logloss:0.38927
# [96]	validation_0-logloss:0.37989	validation_1-logloss:0.38060
# [93]	validation_0-logloss:0.38394	validation_1-logloss:0.38448
# [69]	validation_0-logloss:0.42116	validation_1-logloss:0.42204
# [65]	validation_0-logloss:0.42991	validation_1-logloss:0.43082
# [92]	validation_0-logloss:0.38518	validation_1-logloss:0.38609
# [63]	validation_0-logloss:0.43440	validation_1-logloss:0.43479
# [86]	validation_0-logloss:0.39424	validation_1-logloss:0.39495
# [91]	validation_0-logloss:0.38693	validation_1-logloss:0.38780
# [94]	validation_0-logloss:0.38252	validation_1-logloss:0.38306
# [97]	validation_0-logloss:0.37855	validation_1-logloss:0.37923
# [87]	validation_0-logloss:0.39268	validation_1-logloss:0.39340
# [70]	validation_0-logloss:0.41910	validation_1-logloss:0.41998
# [66]	validation_0-logloss:0.42772	validation_1-logloss:0.42861
# [93]	validation_0-logloss:0.38374	validation_1-logloss:0.38466
# [92]	validation_0-logloss:0.38549	validation_1-logloss:0.38635
# [95]	validation_0-logloss:0.38113	validation_1-logloss:0.38167
# [64]	validation_0-logloss:0.43212	validation_1-logloss:0.43254
# [98]	validation_0-logloss:0.37720	validation_1-logloss:0.37787
# [88]	validation_0-logloss:0.39113	validation_1-logloss:0.39186
# [94]	validation_0-logloss:0.38233	validation_1-logloss:0.38325
# [71]	validation_0-logloss:0.41704	validation_1-logloss:0.41796
# [67]	validation_0-logloss:0.42555	validation_1-logloss:0.42646
# [93]	validation_0-logloss:0.38404	validation_1-logloss:0.38490
# [96]	validation_0-logloss:0.37976	validation_1-logloss:0.38031
# [89]	validation_0-logloss:0.38961	validation_1-logloss:0.39034
# [65]	validation_0-logloss:0.42990	validation_1-logloss:0.43029
# [99]	validation_0-logloss:0.37589	validation_1-logloss:0.37656
# [95]	validation_0-logloss:0.38094	validation_1-logloss:0.38186
# [68]	validation_0-logloss:0.42342	validation_1-logloss:0.42433
# [94]	validation_0-logloss:0.38261	validation_1-logloss:0.38348
# [72]	validation_0-logloss:0.41504	validation_1-logloss:0.41595
# [97]	validation_0-logloss:0.37841	validation_1-logloss:0.37896
# [90]	validation_0-logloss:0.38811	validation_1-logloss:0.38885
# [96]	validation_0-logloss:0.37956	validation_1-logloss:0.38050
# [100]	validation_0-logloss:0.37460	validation_1-logloss:0.37523
# [73]	validation_0-logloss:0.41305	validation_1-logloss:0.41398
# [95]	validation_0-logloss:0.38123	validation_1-logloss:0.38209
# [98]	validation_0-logloss:0.37708	validation_1-logloss:0.37761
# [66]	validation_0-logloss:0.42768	validation_1-logloss:0.42811
# [91]	validation_0-logloss:0.38664	validation_1-logloss:0.38738
# [69]	validation_0-logloss:0.42133	validation_1-logloss:0.42222
# [97]	validation_0-logloss:0.37822	validation_1-logloss:0.37916
# [101]	validation_0-logloss:0.37332	validation_1-logloss:0.37393
# [74]	validation_0-logloss:0.41111	validation_1-logloss:0.41202
# [96]	validation_0-logloss:0.37985	validation_1-logloss:0.38071
# [99]	validation_0-logloss:0.37576	validation_1-logloss:0.37631
# [67]	validation_0-logloss:0.42552	validation_1-logloss:0.42595
# [75]	validation_0-logloss:0.40919	validation_1-logloss:0.41011
# [102]	validation_0-logloss:0.37205	validation_1-logloss:0.37264
# [100]	validation_0-logloss:0.37448	validation_1-logloss:0.37502
# [92]	validation_0-logloss:0.38517	validation_1-logloss:0.38591
# [97]	validation_0-logloss:0.37848	validation_1-logloss:0.37935
# [98]	validation_0-logloss:0.37689	validation_1-logloss:0.37783
# [70]	validation_0-logloss:0.41926	validation_1-logloss:0.42015
# [101]	validation_0-logloss:0.37319	validation_1-logloss:0.37371
# [99]	validation_0-logloss:0.37557	validation_1-logloss:0.37651
# [103]	validation_0-logloss:0.37081	validation_1-logloss:0.37141
# [68]	validation_0-logloss:0.42339	validation_1-logloss:0.42381
# [93]	validation_0-logloss:0.38374	validation_1-logloss:0.38449
# [76]	validation_0-logloss:0.40731	validation_1-logloss:0.40822
# [98]	validation_0-logloss:0.37715	validation_1-logloss:0.37801
# [100]	validation_0-logloss:0.37428	validation_1-logloss:0.37522
# [102]	validation_0-logloss:0.37193	validation_1-logloss:0.37242
# [71]	validation_0-logloss:0.41721	validation_1-logloss:0.41811
# [104]	validation_0-logloss:0.36958	validation_1-logloss:0.37016
# [94]	validation_0-logloss:0.38233	validation_1-logloss:0.38306
# [99]	validation_0-logloss:0.37583	validation_1-logloss:0.37670
# [101]	validation_0-logloss:0.37300	validation_1-logloss:0.37395
# [69]	validation_0-logloss:0.42129	validation_1-logloss:0.42171
# [103]	validation_0-logloss:0.37067	validation_1-logloss:0.37115
# [77]	validation_0-logloss:0.40544	validation_1-logloss:0.40637
# [105]	validation_0-logloss:0.36839	validation_1-logloss:0.36892
# [102]	validation_0-logloss:0.37175	validation_1-logloss:0.37271
# [100]	validation_0-logloss:0.37453	validation_1-logloss:0.37540
# ...
# [260]	validation_0-logloss:0.28588	validation_1-logloss:0.28608
# [264]	validation_0-logloss:0.28563	validation_1-logloss:0.28546
# [139]	validation_0-logloss:0.32319	validation_1-logloss:0.32505
# [138]	validation_0-logloss:0.32407	validation_1-logloss:0.32634
# [69]	validation_0-logloss:0.41706	validation_1-logloss:0.41848
# [140]	validation_0-logloss:0.32246	validation_1-logloss:0.32467
# [261]	validation_0-logloss:0.28574	validation_1-logloss:0.28593
# [265]	validation_0-logloss:0.28551	validation_1-logloss:0.28532
# [41]	validation_0-logloss:0.48866	validation_1-logloss:0.49110
# [71]	validation_0-logloss:0.41274	validation_1-logloss:0.41419
# [262]	validation_0-logloss:0.28559	validation_1-logloss:0.28579
# [266]	validation_0-logloss:0.28538	validation_1-logloss:0.28521
# [140]	validation_0-logloss:0.32240	validation_1-logloss:0.32429
# [139]	validation_0-logloss:0.32328	validation_1-logloss:0.32557
# [141]	validation_0-logloss:0.32170	validation_1-logloss:0.32391
# [70]	validation_0-logloss:0.41494	validation_1-logloss:0.41637
# [72]	validation_0-logloss:0.41068	validation_1-logloss:0.41214
# [263]	validation_0-logloss:0.28547	validation_1-logloss:0.28566
# [267]	validation_0-logloss:0.28525	validation_1-logloss:0.28507
# [264]	validation_0-logloss:0.28533	validation_1-logloss:0.28552
# [141]	validation_0-logloss:0.32163	validation_1-logloss:0.32354
# [42]	validation_0-logloss:0.48535	validation_1-logloss:0.48784
# [140]	validation_0-logloss:0.32251	validation_1-logloss:0.32481
# [268]	validation_0-logloss:0.28512	validation_1-logloss:0.28495
# [71]	validation_0-logloss:0.41285	validation_1-logloss:0.41430
# [73]	validation_0-logloss:0.40865	validation_1-logloss:0.41013
# [265]	validation_0-logloss:0.28518	validation_1-logloss:0.28536
# [142]	validation_0-logloss:0.32094	validation_1-logloss:0.32318
# [142]	validation_0-logloss:0.32087	validation_1-logloss:0.32280
# [269]	validation_0-logloss:0.28500	validation_1-logloss:0.28482
# [266]	validation_0-logloss:0.28505	validation_1-logloss:0.28523
# [72]	validation_0-logloss:0.41080	validation_1-logloss:0.41227
# [74]	validation_0-logloss:0.40666	validation_1-logloss:0.40817
# [143]	validation_0-logloss:0.32012	validation_1-logloss:0.32207
# [270]	validation_0-logloss:0.28487	validation_1-logloss:0.28469
# [141]	validation_0-logloss:0.32173	validation_1-logloss:0.32406
# [143]	validation_0-logloss:0.32019	validation_1-logloss:0.32245
# [267]	validation_0-logloss:0.28489	validation_1-logloss:0.28507
# [73]	validation_0-logloss:0.40877	validation_1-logloss:0.41027
# [271]	validation_0-logloss:0.28475	validation_1-logloss:0.28456
# [43]	validation_0-logloss:0.48209	validation_1-logloss:0.48463
# [75]	validation_0-logloss:0.40470	validation_1-logloss:0.40623
# [268]	validation_0-logloss:0.28477	validation_1-logloss:0.28495
# [272]	validation_0-logloss:0.28463	validation_1-logloss:0.28444
# [144]	validation_0-logloss:0.31937	validation_1-logloss:0.32134
# [144]	validation_0-logloss:0.31946	validation_1-logloss:0.32172
# [142]	validation_0-logloss:0.32097	validation_1-logloss:0.32332
# [269]	validation_0-logloss:0.28462	validation_1-logloss:0.28479
# [273]	validation_0-logloss:0.28451	validation_1-logloss:0.28433
# [76]	validation_0-logloss:0.40276	validation_1-logloss:0.40429
# [74]	validation_0-logloss:0.40678	validation_1-logloss:0.40831
# [44]	validation_0-logloss:0.47887	validation_1-logloss:0.48147
# [145]	validation_0-logloss:0.31865	validation_1-logloss:0.32063
# [270]	validation_0-logloss:0.28450	validation_1-logloss:0.28467
# [145]	validation_0-logloss:0.31873	validation_1-logloss:0.32101
# [274]	validation_0-logloss:0.28439	validation_1-logloss:0.28421
# [146]	validation_0-logloss:0.31793	validation_1-logloss:0.31992
# [146]	validation_0-logloss:0.31802	validation_1-logloss:0.32032
# [77]	validation_0-logloss:0.40085	validation_1-logloss:0.40239
# [143]	validation_0-logloss:0.32023	validation_1-logloss:0.32259
# [271]	validation_0-logloss:0.28435	validation_1-logloss:0.28451
# [275]	validation_0-logloss:0.28428	validation_1-logloss:0.28409
# [75]	validation_0-logloss:0.40482	validation_1-logloss:0.40636
# [45]	validation_0-logloss:0.47572	validation_1-logloss:0.47837
# [272]	validation_0-logloss:0.28423	validation_1-logloss:0.28439
# [276]	validation_0-logloss:0.28417	validation_1-logloss:0.28398
# [147]	validation_0-logloss:0.31723	validation_1-logloss:0.31923
# [144]	validation_0-logloss:0.31947	validation_1-logloss:0.32187
# [78]	validation_0-logloss:0.39898	validation_1-logloss:0.40053
# [277]	validation_0-logloss:0.28406	validation_1-logloss:0.28387
# [147]	validation_0-logloss:0.31731	validation_1-logloss:0.31961
# [273]	validation_0-logloss:0.28412	validation_1-logloss:0.28427
# [278]	validation_0-logloss:0.28395	validation_1-logloss:0.28375
# [76]	validation_0-logloss:0.40289	validation_1-logloss:0.40445
# [279]	validation_0-logloss:0.28384	validation_1-logloss:0.28365
# [274]	validation_0-logloss:0.28398	validation_1-logloss:0.28413
# [145]	validation_0-logloss:0.31876	validation_1-logloss:0.32116
# [79]	validation_0-logloss:0.39712	validation_1-logloss:0.39869
# [148]	validation_0-logloss:0.31654	validation_1-logloss:0.31854
# [46]	validation_0-logloss:0.47261	validation_1-logloss:0.47531
# [148]	validation_0-logloss:0.31661	validation_1-logloss:0.31892
# [275]	validation_0-logloss:0.28384	validation_1-logloss:0.28398
# [280]	validation_0-logloss:0.28373	validation_1-logloss:0.28354
# [77]	validation_0-logloss:0.40098	validation_1-logloss:0.40256
# [146]	validation_0-logloss:0.31806	validation_1-logloss:0.32046
# [80]	validation_0-logloss:0.39530	validation_1-logloss:0.39690
# [281]	validation_0-logloss:0.28363	validation_1-logloss:0.28343
# [276]	validation_0-logloss:0.28373	validation_1-logloss:0.28388
# [78]	validation_0-logloss:0.39910	validation_1-logloss:0.40071
# [149]	validation_0-logloss:0.31584	validation_1-logloss:0.31786
# [149]	validation_0-logloss:0.31593	validation_1-logloss:0.31826
# [277]	validation_0-logloss:0.28359	validation_1-logloss:0.28374
# [47]	validation_0-logloss:0.46956	validation_1-logloss:0.47230
# [282]	validation_0-logloss:0.28352	validation_1-logloss:0.28332
# [147]	validation_0-logloss:0.31736	validation_1-logloss:0.31978
# [81]	validation_0-logloss:0.39349	validation_1-logloss:0.39511
# [278]	validation_0-logloss:0.28349	validation_1-logloss:0.28363
# [79]	validation_0-logloss:0.39726	validation_1-logloss:0.39888
# [150]	validation_0-logloss:0.31517	validation_1-logloss:0.31720
# [283]	validation_0-logloss:0.28342	validation_1-logloss:0.28322
# [279]	validation_0-logloss:0.28335	validation_1-logloss:0.28349
# [150]	validation_0-logloss:0.31525	validation_1-logloss:0.31758
# [82]	validation_0-logloss:0.39172	validation_1-logloss:0.39335
# [148]	validation_0-logloss:0.31667	validation_1-logloss:0.31911
# [284]	validation_0-logloss:0.28332	validation_1-logloss:0.28312
# [280]	validation_0-logloss:0.28325	validation_1-logloss:0.28339
# [80]	validation_0-logloss:0.39544	validation_1-logloss:0.39707
# [48]	validation_0-logloss:0.46655	validation_1-logloss:0.46933
# [151]	validation_0-logloss:0.31458	validation_1-logloss:0.31691
# [285]	validation_0-logloss:0.28322	validation_1-logloss:0.28302
# [151]	validation_0-logloss:0.31450	validation_1-logloss:0.31653
# [281]	validation_0-logloss:0.28314	validation_1-logloss:0.28327
# [286]	validation_0-logloss:0.28312	validation_1-logloss:0.28292
# [83]	validation_0-logloss:0.38998	validation_1-logloss:0.39161
# [149]	validation_0-logloss:0.31600	validation_1-logloss:0.31844
# [282]	validation_0-logloss:0.28304	validation_1-logloss:0.28317
# [81]	validation_0-logloss:0.39364	validation_1-logloss:0.39529
# [287]	validation_0-logloss:0.28302	validation_1-logloss:0.28282
# [283]	validation_0-logloss:0.28291	validation_1-logloss:0.28304
# [152]	validation_0-logloss:0.31392	validation_1-logloss:0.31627
# [152]	validation_0-logloss:0.31385	validation_1-logloss:0.31589
# [150]	validation_0-logloss:0.31533	validation_1-logloss:0.31779
# [84]	validation_0-logloss:0.38825	validation_1-logloss:0.38992
# [288]	validation_0-logloss:0.28292	validation_1-logloss:0.28273
# [284]	validation_0-logloss:0.28281	validation_1-logloss:0.28294
# [153]	validation_0-logloss:0.31327	validation_1-logloss:0.31564
# [82]	validation_0-logloss:0.39187	validation_1-logloss:0.39352
# [285]	validation_0-logloss:0.28270	validation_1-logloss:0.28284
# [49]	validation_0-logloss:0.46358	validation_1-logloss:0.46642
# [289]	validation_0-logloss:0.28282	validation_1-logloss:0.28263
# [286]	validation_0-logloss:0.28260	validation_1-logloss:0.28274
# [85]	validation_0-logloss:0.38656	validation_1-logloss:0.38823
# [151]	validation_0-logloss:0.31468	validation_1-logloss:0.31714
# [153]	validation_0-logloss:0.31321	validation_1-logloss:0.31524
# [290]	validation_0-logloss:0.28273	validation_1-logloss:0.28255
# [287]	validation_0-logloss:0.28249	validation_1-logloss:0.28264
# [154]	validation_0-logloss:0.31262	validation_1-logloss:0.31500
# [83]	validation_0-logloss:0.39011	validation_1-logloss:0.39179
# [288]	validation_0-logloss:0.28240	validation_1-logloss:0.28255
# [152]	validation_0-logloss:0.31403	validation_1-logloss:0.31651
# [291]	validation_0-logloss:0.28263	validation_1-logloss:0.28246
# [86]	validation_0-logloss:0.38488	validation_1-logloss:0.38658
# [154]	validation_0-logloss:0.31257	validation_1-logloss:0.31460
# [50]	validation_0-logloss:0.46067	validation_1-logloss:0.46354
# [289]	validation_0-logloss:0.28230	validation_1-logloss:0.28245
# [292]	validation_0-logloss:0.28254	validation_1-logloss:0.28237
# [84]	validation_0-logloss:0.38839	validation_1-logloss:0.39010
# [155]	validation_0-logloss:0.31200	validation_1-logloss:0.31439
# [153]	validation_0-logloss:0.31339	validation_1-logloss:0.31588
# [290]	validation_0-logloss:0.28220	validation_1-logloss:0.28236
# [87]	validation_0-logloss:0.38324	validation_1-logloss:0.38494
# [293]	validation_0-logloss:0.28245	validation_1-logloss:0.28229
# [155]	validation_0-logloss:0.31194	validation_1-logloss:0.31398
# [294]	validation_0-logloss:0.28236	validation_1-logloss:0.28220
# [85]	validation_0-logloss:0.38670	validation_1-logloss:0.38843
# [291]	validation_0-logloss:0.28210	validation_1-logloss:0.28227
# [295]	validation_0-logloss:0.28224	validation_1-logloss:0.28209
# [51]	validation_0-logloss:0.45779	validation_1-logloss:0.46072
# [154]	validation_0-logloss:0.31276	validation_1-logloss:0.31526
# [156]	validation_0-logloss:0.31137	validation_1-logloss:0.31378
# [88]	validation_0-logloss:0.38161	validation_1-logloss:0.38333
# [292]	validation_0-logloss:0.28201	validation_1-logloss:0.28218
# [156]	validation_0-logloss:0.31132	validation_1-logloss:0.31337
# [296]	validation_0-logloss:0.28215	validation_1-logloss:0.28200
# [86]	validation_0-logloss:0.38504	validation_1-logloss:0.38678
# [293]	validation_0-logloss:0.28192	validation_1-logloss:0.28209
# [157]	validation_0-logloss:0.31075	validation_1-logloss:0.31318
# [297]	validation_0-logloss:0.28206	validation_1-logloss:0.28193
# [155]	validation_0-logloss:0.31213	validation_1-logloss:0.31465
# [89]	validation_0-logloss:0.38002	validation_1-logloss:0.38175
# [294]	validation_0-logloss:0.28183	validation_1-logloss:0.28200
# [52]	validation_0-logloss:0.45497	validation_1-logloss:0.45794
# [298]	validation_0-logloss:0.28198	validation_1-logloss:0.28183
# [158]	validation_0-logloss:0.31014	validation_1-logloss:0.31259
# [87]	validation_0-logloss:0.38338	validation_1-logloss:0.38516
# [157]	validation_0-logloss:0.31071	validation_1-logloss:0.31276
# [295]	validation_0-logloss:0.28174	validation_1-logloss:0.28191
# [90]	validation_0-logloss:0.37843	validation_1-logloss:0.38018
# [159]	validation_0-logloss:0.30954	validation_1-logloss:0.31201
# [156]	validation_0-logloss:0.31152	validation_1-logloss:0.31404
# [299]	validation_0-logloss:0.28189	validation_1-logloss:0.28175
# [296]	validation_0-logloss:0.28165	validation_1-logloss:0.28183
# [88]	validation_0-logloss:0.38177	validation_1-logloss:0.38355
# [300]	validation_0-logloss:0.28181	validation_1-logloss:0.28167
# [297]	validation_0-logloss:0.28155	validation_1-logloss:0.28175
# [160]	validation_0-logloss:0.30895	validation_1-logloss:0.31143
# [53]	validation_0-logloss:0.45217	validation_1-logloss:0.45520
# [158]	validation_0-logloss:0.31011	validation_1-logloss:0.31217
# [157]	validation_0-logloss:0.31092	validation_1-logloss:0.31345
# [91]	validation_0-logloss:0.37688	validation_1-logloss:0.37865
# [301]	validation_0-logloss:0.28173	validation_1-logloss:0.28158
# [302]	validation_0-logloss:0.28165	validation_1-logloss:0.28151
# [298]	validation_0-logloss:0.28147	validation_1-logloss:0.28166
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_180/4116675342.py in <module>
#      14     clf = XGBClassifier()
#      15     grid = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring="f1_macro", verbose=2)
# ---> 16     grid.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], early_stopping_rounds=20)
#      17
#      18     mlflow.log_metric("f1-score", grid.cv_results_["mean_test_score"][grid.best_index_])
#
# ~/diplodatos-grupo2/env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/diplodatos-grupo2/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~/diplodatos-grupo2/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1294     def _run_search(self, evaluate_candidates):
#    1295         """Search all candidates in param_grid"""
# -> 1296         evaluate_candidates(ParameterGrid(self.param_grid))
#    1297
#    1298
#
# ~/diplodatos-grupo2/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# ~/diplodatos-grupo2/env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/diplodatos-grupo2/env/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/diplodatos-grupo2/env/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import SCORERS
SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'top_k_accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %%
model = xgb.XGBClassifier()

param_grid = {
    'pca__n_components': [5, 10, 15, 20, 25, 30],
    'model__max_depth': [2, 3, 5, 7, 10],
    'model__n_estimators': [10, 100, 500],
}

grid = GridSearchCV(pipeline, param_grid, cv=5, n_jobs=-1, scoring='roc_auc')

# %% [raw]
# %%time
#
# grid.fit(X_train, y_train)

# %% [raw]
# mean_score = grid.cv_results_["mean_test_score"][grid.best_index_]
# std_score = grid.cv_results_["std_test_score"][grid.best_index_]
#
# grid.best_params_, mean_score, std_score
#
# print(f"Best parameters: {grid.best_params_}")
# print(f"Mean CV score: {mean_score: .6f}")
# print(f"Standard deviation of CV score: {std_score: .6f}")

# %% [markdown]
# #### Randomized Search

# %%
# Este ejemplo es muy similar al anterior, y deberíamos lograr unos parámetros parecidos en mucho menos tiempo

# %% [markdown]
# ### Feature importance y explainability

# %%
import xgboost as xgb
variables_numericas = ['cons.price.idx', 'cons.conf.idx', 'age','duration']
variables_categoricas = ['education', 'marital','job', 'contact', 'day_of_week']

# Filtramos las variables que seleccionamos
X_t = X_train[variables_categoricas + variables_numericas]

pipeline_numerico = Pipeline([
                             ('standard_scaler', StandardScaler()),
                            ])

pipeline_completo = ColumnTransformer([('num', pipeline_numerico, variables_numericas),
                                   ('cat', OneHotEncoder(), variables_categoricas),
                                  ])

pipeline_modelo = Pipeline([('preprocess', pipeline_completo),
                            ('xgb', xgb.XGBClassifier())])

# %%
pipeline_modelo.fit(X_t, y_train)

# %% [markdown]
# #### Obtener los nombres de las variables

# %%
# Si realizamos one hot encoding, vamos a tener el problema de que se incrementan el numero de features y necesitamos la nueva lista.
numeric_features = variables_numericas
cat_features = pipeline_modelo.named_steps['preprocess'].transformers_[1][1].get_feature_names(variables_categoricas)

# %% [markdown]
# #### Feature importance utilizando XGBoost

# %%
onehot_columns = np.array(cat_features)
numeric_features_list = np.array(numeric_features)
numeric_features_list = np.append(numeric_features_list, onehot_columns)

# %%
# Es necesario ordenar las los valores del feature importance (utilizamos argsort para tener el orden de los indices)
sorted_idx = pipeline_modelo[1].feature_importances_.argsort()
plt.barh(numeric_features_list[sorted_idx], pipeline_modelo[1].feature_importances_[sorted_idx])
plt.xlabel("Xgboost Feature Importance")
plt.show()

# %% [markdown]
# #### Feature importance utilizando eli5

# %%
import eli5
# Utilizar eli5 nos resuelve el problema de ordenar las columnas

# %%
onehot_columns = cat_features
features_list = list(numeric_features)
features_list.extend(onehot_columns)

# %%
eli5.explain_weights(pipeline_modelo[1], top=50, feature_names=features_list)

# %% [markdown]
# #### Utilizar SHAP para obtener feature importance y expainability de las predicciones (opcional)

# %% [markdown]
# Como opcional, podemos utilizar la librería SHAP que nos muestra un tipo de explainability por cada predicción. Estas pueden ser agregadas para obtener un feature importance global del modelo.

# %% [markdown]
# https://shap.readthedocs.io/en/latest/example_notebooks/tabular_examples/tree_based_models/Census%20income%20classification%20with%20XGBoost.html
